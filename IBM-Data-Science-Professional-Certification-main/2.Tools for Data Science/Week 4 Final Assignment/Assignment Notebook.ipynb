# %% [markdown]
# ## My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ## Hasmitavani

# %% [markdown]
# *   BBA student
# *   Java programmer

# %% [markdown]
# *I am interested in data science because I do study economics and would like to be in data analysis.*

# %% [markdown]
# **This below will print the sum of n natural numbers**

# %%
def sumofnaturalno(n):
    return (n*(n+1))/2

sumofnaturalno(100)
# Out:
# 5050.0

# %%
print('Done')
# Out:
# Done
